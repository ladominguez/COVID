# %%
from obspy import read, read_inventory
from obspy.signal import PPSD
from obspy.io.xseed import Parser
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
st  = read('2020*.IG.MOIG.HHZ.sac')
st.merge(fill_value=0.0)
inv = read_inventory('MOIG.RESP',format='RESP') 
tr  = st.select(channel="HHZ")[0]
#tr.detrend("demean")
#tr.detrend("linear")
#trf=tr.filter('bandpass', freqmin=5, freqmax=20)
ppsd = PPSD(tr.stats, metadata=inv,overlap=0.0)
tr.plot();

# %%
ppsd.add(tr)
# Out:
# True

# %%
f=ppsd.psd_periods
P=ppsd.psd_values
#ppsd.plot_temporal([0.1])
ppsd.plot_temporal([0.1], filename='MOIG_JUL.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
